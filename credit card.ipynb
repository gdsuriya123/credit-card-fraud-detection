# %%
import sys
import numpy
import pandas
import matplotlib
import seaborn
import scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/credit card.csv')

# %%
print(data.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data = data.sample(frac=0.1, random_state = 1)
print(data.shape)
print(data.describe())
# Out:
# (2041, 31)
#                Time           V1           V2           V3           V4  \
# count   2041.000000  2041.000000  2041.000000  2041.000000  2041.000000
# mean   15927.432141    -0.274265     0.272235     0.729972     0.282867
# std    10631.072850     1.947707     1.522860     1.900937     1.496923
# min        2.000000   -25.942434   -25.313252   -27.368650    -5.172595
# 25%     5087.000000    -0.997891    -0.305382     0.338259    -0.646429
# 50%    15896.000000    -0.323126     0.252353     0.903829     0.220899
# 75%    26627.000000     1.163592     0.851497     1.546910     1.105482
# max    31023.000000     1.610634    14.601998     3.934998    11.864868
#
#                 V5           V6           V7           V8           V9  ...  \
# count  2041.000000  2041.000000  2041.000000  2041.000000  2041.000000  ...
# mean     -0.174838     0.111567    -0.123493     0.025499     0.624943  ...
# std       1.445582     1.327536     1.400878     1.371230     1.314326  ...
# min     -19.104033   -10.072437   -18.261393   -23.632502    -7.175097  ...
# 25%      -0.706566    -0.648589    -0.574250    -0.172020    -0.228312  ...
# 50%      -0.194866    -0.166012    -0.056240     0.020846     0.598739  ...
# 75%       0.344182     0.451480     0.451089     0.265808     1.367111  ...
# max      11.974269     6.908959     9.656752    17.052566    10.326133  ...
#
#                V21          V22          V23          V24          V25  \
# count  2041.000000  2041.000000  2041.000000  2041.000000  2041.000000
# mean     -0.047518    -0.155974    -0.024760     0.006111     0.122649
# std       0.795282     0.620267     0.397055     0.586219     0.432015
# min     -11.273890    -4.067605    -6.869451    -2.153050    -2.640366
# 25%      -0.260352    -0.593787    -0.176927    -0.339190    -0.141869
# 50%      -0.118953    -0.128125    -0.044992     0.052393     0.158307
# 75%       0.049283     0.241706     0.083351     0.388210     0.396024
# max      11.210748     3.661957     4.095021     1.132342     1.820378
#
#                V26          V27          V28       Amount        Class
# count  2041.000000  2041.000000  2041.000000  2041.000000  2041.000000
# mean      0.038636     0.016474     0.007172    70.839564     0.004410
# std       0.531579     0.374979     0.225450   244.780660     0.066275
# min      -1.291803    -7.057087    -2.143115     0.000000     0.000000
# 25%      -0.333320    -0.066978    -0.011179     5.630000     0.000000
# 50%      -0.014780     0.003622     0.018495    15.950000     0.000000
# 75%       0.324674     0.101122     0.077066    55.000000     0.000000
# max       3.463246     2.698394     2.253256  7879.420000     1.000000
#
# [8 rows x 31 columns]

# %%
data.hist(figsize = (20, 20))
plt.show()

# %%
Fraud = data[data['Class'] == 1]
Valid = data[data['Class'] == 0]

outlier_fraction = len(Fraud)/float(len(Valid))
print(outlier_fraction)

print('Fraud Cases: {}'.format(len(data[data['Class'] == 1])))
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 0.0044291338582677165
# Fraud Cases: 9
# Valid Transactions: 2032

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
columns = data.columns.tolist()
columns = [c for c in columns if c not in ["Class"]]
target = "Class"
X = data[columns]
Y = data[target]
print(X.shape)
print(Y.shape)
# Out:
# (2041, 30)
# (2041,)
